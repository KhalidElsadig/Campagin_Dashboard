# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('extended_techglow_qualtrics_data.csv')
df
# Out:
#      ResponseID        StartDate          EndDate   Platform  Rating  \
# 0             1  5/19/2023 21:57    9/4/2023 5:02  Instagram       2
# 1             2   7/1/2023 20:51  9/14/2023 19:12   LinkedIn       5
# 2             3  5/26/2023 22:25    9/7/2023 3:48   Facebook       4
# 3             4   5/25/2023 9:56   9/7/2023 12:55  Instagram       2
# 4             5    6/3/2023 6:51    9/7/2023 3:01   Facebook       5
# ..          ...              ...              ...        ...     ...
# 995         996  8/28/2023 10:48  9/17/2023 19:09  Instagram       4
# 996         997    5/6/2023 1:29   9/19/2023 9:47    Twitter       5
# 997         998  7/22/2023 17:23  9/17/2023 20:38   Facebook       5
# 998         999   5/12/2023 1:34   9/19/2023 6:43    Twitter       4
# 999        1000   5/31/2023 5:32   9/2/2023 10:55   Facebook       5
#
#                        Feedback PurchaseIntention             Gender  Age  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ResponseID         1000 non-null   int64
#  1   StartDate          1000 non-null   object
#  2   EndDate            1000 non-null   object
#  3   Platform           1000 non-null   object
#  4   Rating             1000 non-null   int64
#  5   Feedback           1000 non-null   object
#  6   PurchaseIntention  1000 non-null   object
#  7   Gender             1000 non-null   object
#  8   Age                1000 non-null   int64
#  9   Country            1000 non-null   object
#  10  Occupation         1000 non-null   object
#  11  ProductVersion     1000 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 93.9+ KB

# %%
bins = [18, 24, 34, 44, 54, np.inf]
labels = ['18-24', '25-34', '35-44', '45-54', '55+']
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)
df
# Out:
#      ResponseID        StartDate          EndDate   Platform  Rating  \
# 0             1  5/19/2023 21:57    9/4/2023 5:02  Instagram       2
# 1             2   7/1/2023 20:51  9/14/2023 19:12   LinkedIn       5
# 2             3  5/26/2023 22:25    9/7/2023 3:48   Facebook       4
# 3             4   5/25/2023 9:56   9/7/2023 12:55  Instagram       2
# 4             5    6/3/2023 6:51    9/7/2023 3:01   Facebook       5
# ..          ...              ...              ...        ...     ...
# 995         996  8/28/2023 10:48  9/17/2023 19:09  Instagram       4
# 996         997    5/6/2023 1:29   9/19/2023 9:47    Twitter       5
# 997         998  7/22/2023 17:23  9/17/2023 20:38   Facebook       5
# 998         999   5/12/2023 1:34   9/19/2023 6:43    Twitter       4
# 999        1000   5/31/2023 5:32   9/2/2023 10:55   Facebook       5
#
#                        Feedback PurchaseIntention             Gender  Age  \
# ...

# %%
df['Start_Date'] = pd.to_datetime(df['StartDate']).dt.date
df['Start_Time'] = pd.to_datetime(df['StartDate']).dt.time
df['End_Date'] = pd.to_datetime(df['EndDate']).dt.date
df['End_Time'] = pd.to_datetime(df['EndDate']).dt.time
df
# Out:
#      ResponseID        StartDate          EndDate   Platform  Rating  \
# 0             1  5/19/2023 21:57    9/4/2023 5:02  Instagram       2
# 1             2   7/1/2023 20:51  9/14/2023 19:12   LinkedIn       5
# 2             3  5/26/2023 22:25    9/7/2023 3:48   Facebook       4
# 3             4   5/25/2023 9:56   9/7/2023 12:55  Instagram       2
# 4             5    6/3/2023 6:51    9/7/2023 3:01   Facebook       5
# ..          ...              ...              ...        ...     ...
# 995         996  8/28/2023 10:48  9/17/2023 19:09  Instagram       4
# 996         997    5/6/2023 1:29   9/19/2023 9:47    Twitter       5
# 997         998  7/22/2023 17:23  9/17/2023 20:38   Facebook       5
# 998         999   5/12/2023 1:34   9/19/2023 6:43    Twitter       4
# 999        1000   5/31/2023 5:32   9/2/2023 10:55   Facebook       5
#
#                        Feedback PurchaseIntention             Gender  Age  \
# ...

# %%
# Define the columns for each data type
int_columns = ["ResponseID", "Rating", "Age"]
date_columns = ["Start_Date", "End_Date"]
category_columns = ["Platform", "PurchaseIntention", "Gender", "Country", "Occupation", "ProductVersion", "Age Group"]
str_columns = ["Feedback"]

# Convert data types
for column in int_columns:
    df[column] = df[column].astype(int)
for column in date_columns:
    df[column] = pd.to_datetime(df[column]).dt.date
for column in category_columns:
    df[column] = df[column].astype("category")
for column in str_columns:
    df[column] = df[column].astype(str)

print(df.dtypes)
# Out:
# ResponseID              int32
# StartDate              object
# EndDate                object
# Platform             category
# Rating                  int32
# Feedback               object
# PurchaseIntention    category
# Gender               category
# Age                     int32
# Country              category
# Occupation           category
# ProductVersion       category
# Age Group            category
# Start_Date             object
# Start_Time             object
# End_Date               object
# End_Time               object
# dtype: object

# %%
df.drop(['StartDate','EndDate'],axis=1,inplace=True)
df
# Out:
#      ResponseID   Platform  Rating                    Feedback  \
# 0             1  Instagram       2     Seems a bit overpriced.
# 1             2   LinkedIn       5              No complaints.
# 2             3   Facebook       4              No complaints.
# 3             4  Instagram       2              No complaints.
# 4             5   Facebook       5  Wish it had more features.
# ..          ...        ...     ...                         ...
# 995         996  Instagram       4     Seems a bit overpriced.
# 996         997    Twitter       5  Wish it had more features.
# 997         998   Facebook       5         Challenging to use.
# 998         999    Twitter       4              No complaints.
# 999        1000   Facebook       5     Seems a bit overpriced.
#
#     PurchaseIntention             Gender  Age    Country Occupation  \
# 0               Maybe               Male   48      India    Teacher
# 1                  No  Prefer not to say   67         UK     Doctor
# ...

# %%
df.to_excel('extended_techglow_qualtrics_data_transformed.xlsx',index=False)
